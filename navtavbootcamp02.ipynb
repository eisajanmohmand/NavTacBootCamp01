# %% [markdown]
# <a href="https://colab.research.google.com/github/eisajanmohmand/NavTacBootCamp01/blob/main/navtavbootcamp02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python If Statement

# %%
a = 10
b = 11
if a < b:
  print('yes, "b" is greater than a')
# Out:
# yes, "b" is greater than a

# %%
x = 2
y = 1
if x >y:
  print('yes, "x" is greater than y ')
# Out:
# yes, "x" is greater than y

# %%
a = 11
b =76
if a <b :
  print('yes, "a" is greater than b')
# Out:
# yes, "a" is greater than b

# %% [markdown]
# Python Elif Statement

# %%
x = 2
y = 2
if x <y :
  print("y is greater than x")
elif x == y :
    print('x and y are equal')
# Out:
# x and y are equal

# %%
a = 5
b = 6
if a < b:
  print("a is less than b")
elif a>b:
  print("a is greater")
# Out:
# a is less than b

# %%
marks = 85
if marks >= 90:
  print("grade a")
elif marks >= 80:
    print('grade b')
elif marks >= 60:
  print("grade d")
# Out:
# grade b

# %%
marks = 44
if marks >= 90:
  print("grade a")
elif marks >= 80:
    print('grade b')
elif marks >= 70:
    print("grade c")
elif marks >= 60:
    print("grade d")
elif marks <= 50:
    print("fail")
# Out:
# fail

# %%
age = 20
if age >= 18:
  print("you can drive")
elif age <= 18:
  print("you can't drive")
# Out:
# you can drive

# %%
a = 10
b= 11
if a > b :
  print("a is greater than b")
elif b == a:
  print("b is greater than c")
else:
  print("b is greater than a")
# Out:
# b is greater than a
