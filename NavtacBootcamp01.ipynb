# %% [markdown]
# <a href="https://colab.research.google.com/github/eisajanmohmand/NavTacBootCamp01/blob/main/NavtacBootcamp01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('helo world')
# Out:
# helo world

# %%
import sys

print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
print(555)
# Out:
# 555

# %%
print(2+2+3)
# Out:
# 7

# %%
print(2*7)
# Out:
# 14

# %%
x =  5
y = 6
print(x)
print(x)
print(y,x)
# Out:
# 5
# 5
# 6 5

# %%
x = 5
x = 'john'
x = 'hello' #it will  print hello
print(x)
# Out:
# hello

# %%
x = 4
y = 'hello'
z = 8.9
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
x = 1
X = 2
print(x,X)
# Out:
# 1 2

# %%
#varibales names
myvar
_my_var
MYVAR
MyVar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2961989346.py in <cell line: 0>()
#       1 #varibales names
# ----> 2 myvar
#       3 _my_var
#       4 MYVAR
#       5 MyVar
#
# NameError: name 'myvar' is not defined

# %%
#Many Values to Multiple Variables
x,y,z ="orange",'apple','banan'
print(x)
print(y)
print(x,y)

# %%
a,b,c,d ="good",'bad','excellent','poor'
print(d)
print(c)
print(b)
print(a)

# %%
#One Value to Multiple Variables
a=b=c= 'apple'
print(a)

# %%
x=y=z =100
print(z)
print(y)
print(x)
# Out:
# 100
# 100
# 100

# %%
#Unpack a Collection
countries = ['pak','ind','ksa',]
x,y,z=countries
print(x)
print(y)
print(z)
# Out:
# pak
# ind
# ksa

# %%
fruits = ['apple','banan','orange']
a,b,c = fruits
print(a)
# Out:
# apple

# %%
#output varibales
x = "python is good"
print(x)
# Out:
# python is good

# %%
y = 'ai'
print(y)
# Out:
# ai

# %%
x = 'eisa'
y = 'jan'
z = 'mohmand'
print(x)
print(x,y)
print(x,y,z)
# Out:
# eisa
# eisa jan
# eisa jan mohmand

# %%
x = 'eisa'
y = '  jan'
print(x+y)
print(x+y)
# Out:
# eisa  jan
# eisa  jan

# %%
x =33
y = 3
print(x+y)
print(x-y)
print(x*y)
# Out:
# 36
# 30
# 99

# %%
#global varibales
x = 'goood'
def myf():
  print('python is ' + x)
myf()
# Out:
# python is goood

# %%
y = "muslim"
def fun():
  print("he is a practiceing" + y)
  fun()

# %%
x = "bad"
def myfun():
  x = "good"
  print("he is "+x)
  myfun
  print("he is "+x)

# %%
y = "good"
def myfunction():
 y = "excellect"
 print("ai is"+ y)
myfunction()
print("ai is" +y)
# Out:
# ai isexcellect
# ai isgood

# %%
x= 'good'
def myfunc():
  x = "bad"
  print("ai is " + x)
myfunc()
#print("ai is"+x)
# Out:
# ai is bad

# %%
# data types
# Text Type:	str
# Numeric Types:	int, float, complex
# Sequence Types:	list, tuple, range
# Mapping Type:	dict
# Set Types:	set, frozenset
# Boolean Type:	bool
# Binary Types:	bytes, bytearray, memoryview

# %%
#int
x = 5
print(type(x))
# Out:
# <class 'int'>

# %%
x = 43
print(type(x))
# Out:
# <class 'int'>

# %%
#float
y = 2.2
print(type(y))
# Out:
# <class 'float'>

# %%
y = 54.4
print(type(y))
# Out:
# <class 'float'>

# %%
#string
z = "hello"
print(type(z))
# Out:
# <class 'str'>

# %%
z = 'world'
print(type(z))
# Out:
# <class 'str'>

# %%
#list
#list is denoted by []
x = ['banana','apple']
print(type(x))
# Out:
# <class 'list'>

# %%
x = [1,2,3]
print(type(x))
# Out:
# <class 'list'>

# %%
#Touple
# Touple is denoted by ()
y = ('a','b','c')
print(type(y))
# Out:
# <class 'tuple'>

# %%
y = (1,223,4,)
print(type(y))
print(y)
# Out:
# <class 'tuple'>
# (1, 223, 4)

# %%
#range
x = range(1,6)
print(type(x))
print(x)
# Out:
# <class 'range'>
# range(1, 6)

# %%
x = range(10)
print(type(x))
print(x)
# Out:
# <class 'range'>
# range(0, 10)

# %%
#set
# difference between set and dict is , and : in set we use (,)and in dict we use (:)
x = {1,3,4}
print(type(x))
print(x)
# Out:
# <class 'set'>
# {1, 3, 4}

# %%
x = {'apple','orange'}
print(type(x))
print(x)
# Out:
# <class 'set'>
# {'apple', 'orange'}

# %%
#dict
y = {1:2,3:4}
print(type(y))
print(y)
# Out:
# <class 'dict'>
# {1: 2, 3: 4}

# %%
y = {'orange':"apple","kiwi":'keno'}
print(type(y))
print(y)
# Out:
# <class 'dict'>
# {'orange': 'apple', 'kiwi': 'keno'}

# %%
#boolan
a =  5
b = 6
x = a > b
print(type(x))
# Out:
# <class 'bool'>

# %%
#py string
x = "hello"
print(x)
# Out:
# hello

# %%
y = 'hello , world'
print(y)
# Out:
# hello , world

# %%
z = 'i am practicing python'
print (z)
# Out:
# i am practicing python

# %%
 x = "hello"
 print(x[1])
# Out:
# e

# %%
x = 'eisajan'
print(x[0:])
# Out:
# eisajan

# %%
y = 'mohmand'
print(y[0:3])
# Out:
# moh

# %%
y = 'hello'
print(y[:3])
# Out:
# hel

# %%
for x in 'banana':
  print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
for y in 'appleee':
 print(y)
# Out:
# a
# p
# p
# l
# e
# e
# e

# %%
#find length
x = "mohmand"
print(len(x))
# Out:
# 7

# %%
x = "banana"
print(len(x))
print(x)
# Out:
# 6
# banana

# %%
#checking string
a = "he is a good boy"
print("is"in a)
# Out:
# True

# %%
x = "sir ubaid is teaching us very well"
print("ubaid"in x)
# Out:
# True

# %%
a = 'we are going to islambad today'
print('they' in a)
# Out:
# False

# %%
#if statement
z = "we are going soon"
if "are" in z:
  print('yes, "are" is present')
# Out:
# yes, "are" is present

# %%
text = "we are free"
if "free" in text:
  print("yes,'free' is present")
# Out:
# yes,'free' is present

# %%
x = "he is good"
if "bad" in x:
  print("yes 'bad' is present")
else:
    print("no, 'bad' is not present")
# Out:
# no, 'bad' is not present

# %%
y = 'university'
if "e" in y:
  print("yes'e' is present")
# Out:
# yes'e' is present

# %%
a = "he is very lucky"
print("'luck' is not in a)")
# Out:
# 'luck' is not in a)

# %%
x = "he is not lucky"
if "good" not in x:
  print("no 'good ' is not present")
# Out:
# no 'good ' is not present

# %%
#slicing string
a = "hellllo"
print(a[0:])
# Out:
# hellllo

# %%
a = "applee"
print(a[1:])
# Out:
# pplee

# %%
a = "book"
print(a[1:3])
# Out:
# oo

# %%
 a = "book"
 print(a[-1:-2])

# %%
a = "mohmand"
print(a[2:5])
# Out:
# hma

# %%
a = " hasnain"
print(a[1:-4])
# Out:
# has

# %%
#modifing string
b = "Going"
print(b.upper())
print(b.lower())
# Out:
# GOING
# going

# %%
b = "EIsa Jan"
print(b.lower())
print(b.upper())
# Out:
# eisa jan
# EISA JAN

# %%
#removing white spaces
b = "hello world    "
print(b.strip())
# Out:
# hello world

# %%
#replacing string
b = "hisa"
print(b.replace("h","e"))
# Out:
# eisa

# %%
b = ' going'
print(b.replace("i","L"))
# Out:
#  goLng

# %%
#SPILT STRING
b = 'kiwi'
print(b.split())
# Out:
# ['kiwi']

# %%
b = 'apple'
print(b.split())
# Out:
# ['apple']

# %%
#String Concatenation or adding
a = "musa"
b = " jan"
print(a+b)
# Out:
# musa jan

# %%
a = "he is "
b = "a good boy"
c = a+b
print(c)
# Out:
# he is a good boy

# %%
#format string
x = "dist mohmand"
text = f"my name essa and i am from  {x}"
print(text)
# Out:
# my name essa and i am from  dist mohmand

# %%
y = "peshawar"
txt = f"i am from {y} the city of flowers"
print(txt)
# Out:
# i am from peshawar the city of flowers

# %%
y = "uni road"
txt = f"encoders bytes is on {y}"
print(txt)
# Out:
# encoders bytes is on uni road

# %%
#Python Booleans
a = 10
b = 20
if a < b :
  print('a is less than b')
else:
  print('b is greater')
# Out:
# a is less than b

# %%
a = 32
b = 43
c = 89
if a > b :
  print('bad')
elif a > c:
  print('good')
else:
  print('excellent')
# Out:
# excellent

# %%
def myfun():
  return True
  if myfun():
    print('go')
  else:
    print('stop')

# %%
#python Operators
sum1 = 10+5
sum2 = sum1+5
sum3 = sum2 +10
print(sum3)
print(sum2)
print(sum1)
# Out:
# 30
# 20
# 15

# %%
print (10+10)
print (10+40)
print (10+132)
print (10+3)
print (10+540)
# Out:
# 20
# 50
# 142
# 13
# 550

# %%
#Python Arithmetic Operators
print(2+2)
print(2*2)
print(2%2)
print(2-2)
print(2/2)
# Out:
# 4
# 4
# 0
# 0
# 1.0

# %%
x = 10
y = 20
print(x+y)
print(x-y)
print(x*y)
print(x//y)
# Out:
# 30
# -10
# 200
# 0

# %%
#Logical Operators
x = 5
print(x > 3 and x < 10)
y = 5

print(y < 5 or y > 10)
# Out:
# True
# False

# %%
x = 2
print(x > 4 and x < 1)
# Out:
# False

# %%
x = 10
print(x > 4 or x < 1)
# Out:
# True

# %%
x = 5
print(x == 5 and x > 3)
# Out:
# True

# %%
#identity
a = "eisa"
b = ' eisa'
c = a
b = c
print(c)
# Out:
# eisa

# %%
#Membership Operators
x = ['a','b','c']
print('c' in x)
# Out:
# True

# %%
y = ['apple','kiwwi']
print('apple' not in y)
# Out:
# False

# %%
z = ['banan ', ' graps']
print('apple' in z)
# Out:
# False

# %%
txt = "Hello to the World"

print("H" in txt)
print("hello" in txt)
print("z" not in txt)
# Out:
# True
# False
# True

# %%
#Operator Precedence
a = ((10+20)-(10+10))
print(a)
# Out:
# 10

# %%
a = ((10+20)*(10+10))
print(a)
# Out:
# 600

# %%
#py list
#List items are ordered, changeable, and allow duplicate values.
mylistt = [1,2,'eisa']
print(mylistt)
# Out:
# [1, 2, 'eisa']

# %%
list = ['ee','ii','ss','aa']
print(list[1:3])
# Out:
# ['ii', 'ss']

# %%
x = [1,2,3,4,5,6,6,6]
print(x)
# Out:
# [1, 2, 3, 4, 5, 6, 6, 6]

# %%
list1 =['djks','iua']
list2 =[2.2,7.3,3.3]
list3 =[1,2,3]
print(list1)
print(list2)
print(list3)
print(list1,list2,list3)
# Out:
# ['djks', 'iua']
# [2.2, 7.3, 3.3]
# [1, 2, 3]
# ['djks', 'iua'] [2.2, 7.3, 3.3] [1, 2, 3]

# %%
#Access Items
a = ['aple','cat','tdgh']
print(a[1])
# Out:
# cat

# %%
a = ['Alex Rivera', 'Mira Chen', 'Jonah Patel', 'Sophie Kim', 'Liam Patel', 'Aria Bennett',]
print(a[1:4])
# Out:
# ['Mira Chen', 'Jonah Patel', 'Sophie Kim']

# %%
a = ['Alex Rivera', 'Mira Chen', 'Jonah Patel', 'Sophie Kim', 'Liam Patel', 'Aria Bennett', 'Niko Silva', 'Zara Ahmed', 'Kai Nakamura', ]
print(a[:7])
# Out:
# ['Alex Rivera', 'Mira Chen', 'Jonah Patel', 'Sophie Kim', 'Liam Patel', 'Aria Bennett', 'Niko Silva']

# %%
a = ['Alex Rivera', 'Mira Chen', 'Jonah Patel', 'Sophie Kim', 'Liam Patel', 'Aria Bennett',]
print(a[-2])
# Out:
# Liam Patel

# %%
#if statement
a = ['Alex ', 'Mira Chen', 'Jonah Patel', 'Sophie Kim', 'Liam Patel', 'Aria Bennett']
if 'alex' in a:
  print("yes 'alex' is present" )

# %%
list = ["apple","kiwi",'orange']
if "apple " in list:
  print('yes, "apple" is present')

# %%
fruit = ["apple","kiwi",'orange']
if "banana" in fruit:
  print('yes, "banana" is present')
else:
  print("no , 'banana' is present")
# Out:
# no , 'banana' is present

# %%
fruits = ["apple", "kiwi", "orange"]

if "banana" in fruits:
    print('yes, "banana" is present')
else:
    print('no, "banana" is not present')
# Out:
# no, "banana" is not present

# %%
#change the list item
list =['apple','kiwi','orange']
list[1] = 'cat'
print(list)
# Out:
# ['apple', 'cat', 'orange']

# %%
list = ["apple", "kiwi", "orange"]
list[2] ='dog'
print(list)
# Out:
# ['apple', 'kiwi', 'dog']

# %%
list = ["apple","cat","dog"]
list[0]='lion'
print(list)
# Out:
# ['lion', 'cat', 'dog']

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist[1:3] = ["blackcurrant", "watermelon"]
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'orange', 'kiwi', 'mango']

# %%
#adding list items
thislist = ["ali","ahmad","ubaid"]
thislist.append  ('huzaifa')
print(thislist)
# Out:
# ['ali', 'ahmad', 'ubaid', 'huzaifa']

# %%
list = [1,2,3,4,5]
list.append(6),list.append(7),list.append(8)
print(list)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
list = [1,2.2,'eisa']
list.append('jan'),list.append('MMD')
print(list)
# Out:
# [1, 2.2, 'eisa', 'jan', 'MMD']

# %%
#add lit and touple
thislist = ["apple", "banana", "cherry"]
thistuple = ("kiwi", "orange")
thislist.extend(thistuple)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'kiwi', 'orange']

# %%
list1 = ['a','b']
touple = (1,2)
list1.extend(touple)
print(list1)
# Out:
# ['a', 'b', 1, 2]

# %%
#remove list item
list = [1,2,3,4]
list.remove(2)
print(list)
# Out:
# [1, 3, 4]

# %%
list = ["ali","car","huzaifa","musa"]
list.remove("car")
print(list)
# Out:
# ['ali', 'huzaifa', 'musa']

# %%
#pop can also be use for removing
li = [1,11,111,1111]
li.pop(0)
print(li)
# Out:
# [11, 111, 1111]

# %%
l = ["apple","banana","cat"]
l.pop(2)
print(l)
# Out:
# ['apple', 'banana']

# %%
LL = [22,221,112,2121,2121,212121,23,32]
del LL[0]
print(LL)
# Out:
# [221, 112, 2121, 2121, 212121, 23, 32]

# %%
#loop list
lst = [1,2,3,4,5]
for a in lst:
  print(a)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
list = ['apple','ball','cat']
for x in list:
  print(x)
# Out:
# apple
# ball
# cat

# %%
list = [1,2,3,4,5,6,7]
for a in list:
  print(a)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
#while loop
list = ["apple","ball","cat"]
i = 0
while i < len(list):
  print(list[i])
  i = i+1
# Out:
# apple
# ball
# cat

# %%
thislist = ["apple", "banana", "cherry"]
i = 0
while i < len(thislist):
  print(thislist[i])
  i = i + 1
# Out:
# apple
# banana
# cherry

# %%
#List Comprehension
fruit = ['apple','banana','kiwi']
new = []
for x in fruit:
  if "a" in x:
    new.append(x)
    print(x)
# Out:
# apple
# banana

# %%
names = ["ali","huzaifa","ubaid",'hassan','basit']
new = []
for y in names:
  if "x"  in y:
    new.append(y)
    print(y)

    #this will print empty set bcx there is no x

# %%
animals = ["dog","cat","lion"]
new = []
for x in animals:
  if "a" in x:
    new.append(x)
    print(new)
    print(x)
# Out:
# ['cat']
# cat

# %%
#Sort Lists
list = ['a','b','d','c']
list.sort()
print(list)
# Out:
# ['a', 'b', 'c', 'd']

# %%
list = [1,2,4,7,6,8,5]
list.sort
print(list)
# Out:
# [1, 2, 4, 7, 6, 8, 5]

# %%
list = [1,2,4,7,6,8,5]
list.sort
for x in list:
  print(x)
print(list)
# Out:
# 1
# 2
# 4
# 7
# 6
# 8
# 5
# [1, 2, 4, 7, 6, 8, 5]

# %%
#Use the copy() method
x = ['huzaif','ali','hassan']
y = x.copy()
print(y)
# Out:
# ['huzaif', 'ali', 'hassan']

# %%
a = [1,2,3,4,5]
b = a.copy()
print(b)
# Out:
# [1, 2, 3, 4, 5]

# %%
x = ['ali','huzaifa','ubaid']
y = x[:]
print(y)
# Out:
# ['ali', 'huzaifa', 'ubaid']

# %%
x = [1,2,3,4,5]
y = x[:]
print(y)
# Out:
# [1, 2, 3, 4, 5]

# %%
#join lists
list1 = [1,2,3]
list2 = ['ali']
list3 = list1+lis2
print(list3)
print(list1+list2)
# Out:
# [1, 2, 3, 'ali']
# [1, 2, 3, 'ali']

# %%
#Python Tuples
#Tuple items are ordered unchangeable and allow duplicate values
mytuples = (1,2,3)
print(mytuples)
# Out:
# (1, 2, 3)

# %%
#it allows duplicate
x = (1,1,1,1,1)
print(x)
# Out:
# (1, 1, 1, 1, 1)

# %%
y = ('a','b','c')
print(len(y))
# Out:
# 3

# %%
x = ('a','b','c')
print(type(x))
# Out:
# <class 'tuple'>

# %%
#Access Tuple Items
x = (1,11,111,1111,112,5,43,53,665)
print(x[2])
print(x[-2])
print(x[2:5])
# Out:
# 111
# 53
# (111, 1111, 112)

# %%
x = (221,2,3,4,5,6)
print(x[:4])
print(x[2:])
# Out:
# (221, 2, 3, 4)
# (3, 4, 5, 6)

# %%
#Check if Item Exists
x = ('apple','cat','lion')
if 'cat' in x:
  print('yes, "cat" is present')
# Out:
# yes, "cat" is present

# %%
y = ('lion','cat','goat')
if "ali" in y:
  print('yes, "ali" is present')
else:
  print('Noo, "ali" is not present')
# Out:
# Noo, "ali" is not present

# %%
#unpack tuples
x = ("cat",'dog')
(cat,*dog)= x
print(dog)
print(cat)
# Out:
# ['dog']
# cat

# %%
#loop in tuples
t = (1,2,3)
for a in t:
 print(a)
# Out:
# 1
# 2
# 3

# %%
tuple = ("orange","apple","kiwi")
for i in range(len(tuple)):
  print(tuple[i])
# Out:
# orange
# apple
# kiwi

# %%
#join tuples
x = (1,2,3)
y = (1,2,3)
z = x +y
print(z)
# Out:
# (1, 2, 3, 1, 2, 3)

# %%
#SETS
#Sets are written with curly brackets
#Unordered
#Unchangeable
#Duplicates Not Allowed

set = {1,2,3}
print(set)
# Out:
# {1, 2, 3}

# %%
#in sets duplicate are not so it will give error
set {'apple','kiwi','apple'}

print(set)
# Out:
#   File "/tmp/ipython-input-638362820.py", line 2
#     set {'apple','kiwi','apple'}
#         ^
# SyntaxError: invalid syntax

# %%
set1 = {1,2,3}
set2 = {"a","c"}
set3 = {True, False}
print(set1)
print(set2)
print(set3)

# %%
set1 = {"abc", 34, True, 40, "male"}
print(set1)
print(type(set1))

# %%
#Access Set Items
set = {1,2,33,4}
for x in set:
  print(x)

# %%
set = {"apple","gowawa"}
print("apple" in set)

# %%
#add
set = {1,2,3}
set.add(55)
print(set)

# %%
set = {1,2,3}
list =[4,5,6]
set.update(list)
print(set)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#removing
set = {1,2,3,4}
set.remove(3)
print(set)
# Out:
# {1, 2, 4}

# %%
set = {"cat","dog"}
set.remove("dog")
print(set)
# Out:
# {'cat'}

# %%
#Remove a random item by using the pop() method
set = {1,2,3,4,5}
set.pop()
print(set)
# Out:
# {2, 3, 4, 5}

# %%
#loops in sets
set = {1,2,3,4,5,8,7,6}
for x in set:
 print (x)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
#jion sets
set1 ={1,2,3,4}
set2 = {7,6,5,4}
set3 = set1.union(set2)
print(set3)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
set = {"a","b","c"}
set1 = {1,2,3}
set3 = set|set1
print(set3)
set.update(set1)
print(set)
# Out:
# {1, 'a', 2, 3, 'c', 'b'}
# {1, 'a', 2, 3, 'c', 'b'}

# %%
set1 = {"a","b","c"}
set2 = {1,2,3}
set3 = {5,5}
set4 = set1|set2|set3
print(set4)
# Out:
# {1, 'a', 2, 3, 5, 'c', 'b'}

# %%
x = ({"apple", "banana", "cherry"})
print(x)
# Out:
# {'banana', 'apple', 'cherry'}

# %%
#Python Dictionaries
dict = {
    "brand":"honda",
    "model":"civic",
    "year":2023
}
print(dict)
# Out:
# {'brand': 'honda', 'model': 'civic', 'year': 2023}

# %%
dict = {
    "name" : "ali",
    "class" : "10",
    "age" : 12
}
print(dict)
print(dict['class'])
print(len(dict))
# Out:
# {'name': 'ali', 'class': '10', 'age': 12}
# 10
# 3

# %%
dict = {
  "brand": "Ford",
  "electric": False,
  "year": 1964,
  "colors": ["red", "white", "blue"]
}
print(dict)
# Out:
# {'brand': 'Ford', 'electric': False, 'year': 1964, 'colors': ['red', 'white', 'blue']}

# %%
#Accessing Items
x = {
    "car":"corola",
    "model":1994
}
y = x["model"]
print(y)
# Out:
# 1994

# %%
y = {
    "name" : "ali",
    "class": 10
}
x = y['name']
print(x)
# Out:
# ali

# %%
car = {
    "brand": "honda",
    "model": "1994"
}

print(car)

car["colour"] = "golden"

print(car)
# Out:
# {'brand': 'honda', 'model': '1994'}
# {'brand': 'honda', 'model': '1994', 'colour': 'golden'}

# %%
#Change Dictionary Items
car = {
    "car": "corola",
    'model': 2026
}
car['model']= 1994
print(car)
# Out:
# {'car': 'corola', 'model': 1994}

# %%
dict = {
    "name" : "ali",
    "class": 12,
    "subject": "sci"
}
print(dict)
dict["school"]= "pms"
print(dict)
# Out:
# {'name': 'ali', 'class': 12, 'subject': 'sci'}
# {'name': 'ali', 'class': 12, 'subject': 'sci', 'school': 'pms'}

# %%
dict = {
    "animal" : "lion",
    "colour": "yellow"
}
print(dict)
dict.pop('colour')
dict.update({"place":"forest"})
print(dict)
# Out:
# {'animal': 'lion', 'colour': 'yellow'}
# {'animal': 'lion', 'place': 'forest'}

# %%
dict = {
    "univ":"aup",
    "year": 4
}
print(dict)
dict.pop("year")
print(dict)
dict.update({"samester":4})
print(dict)
# Out:
# {'univ': 'aup', 'year': 4}
# {'univ': 'aup'}
# {'univ': 'aup', 'samester': 4}

# %%
#copy
dict = {
    "name": "ali"
}
newdict=dict.copy()
print(newdict)
# Out:
# {'name': 'ali'}

# %%
#nasted dict
frnd1 = {
    "name":"ali",
    "class": 12
}
frnd2 = {
    "name":"ubaid",
    "class":10}
frnd3 = {
        "name":"huzaifa",
        "class":9
    }
myfrnd = {
        "frnd1":frnd1,
        "frnd2":frnd2,
        "frnd3":frnd3}
print(myfrnd)
frnd2.update({"school":"pms"})
print(myfrnd)
# Out:
# {'frnd1': {'name': 'ali', 'class': 12}, 'frnd2': {'name': 'ubaid', 'class': 10}, 'frnd3': {'name': 'huzaifa', 'class': 9}}
# {'frnd1': {'name': 'ali', 'class': 12}, 'frnd2': {'name': 'ubaid', 'class': 10, 'school': 'pms'}, 'frnd3': {'name': 'huzaifa', 'class': 9}}
